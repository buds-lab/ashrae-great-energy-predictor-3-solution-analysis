# %%
#!pip install tensorflow==1.14.0

# %%
#!pip install keras==2.2.5

# %%
# import tensorflow as tf
# print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))

# %%
import os
os.environ["PYTHONHASHSEED"] = "13"
os.environ["CUDA_VISIBLE_DEVICES"] = ""

import numpy as np
import tensorflow as tf
import random as rn

# The below is necessary for starting Numpy generated random numbers
# in a well-defined initial state.

np.random.seed(13)

# The below is necessary for starting core Python generated random numbers
# in a well-defined state.

rn.seed(13)

# Force TensorFlow to use single thread.
# Multiple threads are a potential source of non-reproducible results.
# For further details, see: https://stackoverflow.com/questions/42022950/

session_conf = tf.ConfigProto(intra_op_parallelism_threads=1,
                              inter_op_parallelism_threads=1)

from keras import backend as K

# The below tf.set_random_seed() will make random number generation
# in the TensorFlow backend have a well-defined initial state.
# For further details, see:
# https://www.tensorflow.org/api_docs/python/tf/set_random_seed

tf.set_random_seed(13)

sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)
# Out:
# Using TensorFlow backend.

# %%
K.tensorflow_backend._get_available_gpus()
# Out:
# WARNING:tensorflow:From C:\Users\sbbpan\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From C:\Users\sbbpan\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# ['/job:localhost/replica:0/task:0/device:GPU:0']

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 5805342840237687924
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 1426918195
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 6515638258217335041
# physical_device_desc: "device: 0, name: GeForce MX250, pci bus id: 0000:01:00.0, compute capability: 6.1"
# ]

# %%
import gc
import warnings

import lightgbm as lgb
import pandas as pd

from matplotlib import pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler
from tqdm.notebook import tqdm

import keras
from keras.models import Sequential
from keras.layers import BatchNormalization, Dense, Dropout

path_data = "../input/ashrae-energy-prediction/"
path_train = path_data + "train.csv"
path_test = path_data + "test.csv"
path_building = path_data + "building_metadata.csv"
path_weather_train = path_data + "weather_train.csv"
path_weather_test = path_data + "weather_test.csv"

myfavouritenumber = 13
seed = myfavouritenumber

warnings.filterwarnings("ignore")

# %%
site_id = 8

# %%
df_train = pd.read_csv(path_train)
df_test = pd.read_csv(path_test)

building = pd.read_csv(path_building)

weather_train = pd.read_csv(path_weather_train)
weather_test = pd.read_csv(path_weather_test)

weather_train.drop(["sea_level_pressure", "wind_direction", "wind_speed"], axis=1, inplace=True)
weather_test.drop(["sea_level_pressure", "wind_direction", "wind_speed"], axis=1, inplace=True)

weather_train = weather_train.groupby("site_id").apply(lambda group: group.interpolate(limit_direction="both"))
weather_test = weather_test.groupby("site_id").apply(lambda group: group.interpolate(limit_direction="both"))

df_train = df_train.merge(building, on="building_id")
df_test = df_test.merge(building, on="building_id")

df_train = df_train[df_train.site_id == site_id]
df_test = df_test[df_test.site_id == site_id]

df_train = df_train[~((df_train.building_id == 848) & (df_train.meter_reading == 0))]
df_train = df_train[~((df_train.building_id == 815) & (df_train.meter_reading == 0))]

df_train = df_train.merge(weather_train, on=["site_id", "timestamp"], how="left")
df_test = df_test.merge(weather_test, on=["site_id", "timestamp"], how="left")

df_train.timestamp = pd.to_datetime(df_train.timestamp, format='%Y-%m-%d %H:%M:%S')
df_test.timestamp = pd.to_datetime(df_test.timestamp, format='%Y-%m-%d %H:%M:%S')

df_train.building_id = df_train.building_id.astype("str")
df_test.building_id = df_test.building_id.astype("str")

df_train["log_meter_reading"] = np.log1p(df_train.meter_reading)

del building
gc.collect()
# Out:
# 0

# %%
df_train["hour"] = df_train.timestamp.dt.hour.astype("str")
df_test["hour"] = df_test.timestamp.dt.hour.astype("str")

df_train["weekday"] = df_train.timestamp.dt.weekday.astype("str")
df_test["weekday"] = df_test.timestamp.dt.weekday.astype("str")

df_train["month"] = df_train.timestamp.dt.month.astype("str")
df_test["month"] = df_test.timestamp.dt.month.astype("str")

# %%
features = [
    "building_id",
    "square_feet",
    "year_built",
    "floor_count",
    "primary_use",
    "air_temperature",
    "cloud_coverage",
    "dew_temperature",
    "precip_depth_1_hr",
    "hour",
    "weekday",
    "month"
]

# %%
def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
cv = 5
folds = KFold(n_splits = cv, shuffle = False, random_state = seed)

df_cv = []
df_preds = []

# %%
for meter in df_train.meter.unique():
    print("Building Model for site_id", site_id, "and meter", meter)
        
    df_train_site_meter = df_train[df_train.meter == meter].reset_index(drop=True)
    df_test_site_meter = df_test[df_test.meter == meter].reset_index(drop=True)
    
    pred_val = np.zeros(df_train_site_meter.shape[0])
    pred_test = np.zeros(df_test_site_meter.shape[0])

    row_ids_test = df_test_site_meter.row_id
    y_train_site_meter = df_train_site_meter.log_meter_reading.values
    
    df_train_site_meter = df_train_site_meter[features]
    df_test_site_meter = df_test_site_meter[features]

    df_train_site_meter = pd.get_dummies(df_train_site_meter)
    df_test_site_meter = pd.get_dummies(df_test_site_meter)
        
    for k, (train_idx, valid_idx) in enumerate(folds.split(df_train_site_meter, y_train_site_meter)):
        print("Preparing Site:", site_id, ", meter:", meter, ", Fold:", k+1)
        
        X_train, y_train = df_train_site_meter.iloc[train_idx], y_train_site_meter[train_idx]
        X_valid, y_valid = df_train_site_meter.iloc[valid_idx], y_train_site_meter[valid_idx]
        
        X_train.dropna(axis=1, how="all", inplace=True)
        X_train = X_train.loc[:, (X_train != X_train.iloc[0]).any()]

        X_valid = X_valid[X_train.columns]
        X_test = df_test_site_meter[X_train.columns]
        
        df_means = pd.concat([X_train, X_valid, X_test], ignore_index=True).mean()
        X_train.fillna(df_means, inplace=True)
        X_valid.fillna(df_means, inplace=True)
        X_test.fillna(df_means, inplace=True)
        
        sc = MinMaxScaler()
        sc.fit(pd.concat([X_train, X_valid, X_test], ignore_index=True))
        
        X_train = np.array(sc.transform(X_train))
        X_valid = np.array(sc.transform(X_valid))
        X_test = np.array(sc.transform(X_test))
        
        model = Sequential()
        model.add(Dense(512, input_dim=X_train.shape[1], activation="relu", kernel_initializer=keras.initializers.glorot_uniform(seed=seed)))
        model.add(BatchNormalization())
        model.add(Dropout(0.2))
        model.add(Dense(128, activation="tanh", kernel_initializer=keras.initializers.glorot_uniform(seed=seed)))
        model.add(BatchNormalization())
        model.add(Dropout(0.2))
        model.add(Dense(16, activation="tanh", kernel_initializer=keras.initializers.glorot_uniform(seed=seed)))
        model.add(BatchNormalization())
        model.add(Dropout(0.2))
        model.add(Dense(1))
        model.compile(loss=rmse, optimizer="adam")
        
        model_ffnn = model.fit(X_train, y_train, epochs=41, batch_size=1300, validation_data=(X_valid, y_valid), verbose=2, shuffle=False)

        plt.plot(model_ffnn.history["loss"])
        plt.plot(model_ffnn.history["val_loss"])
        plt.title("Loss for Site: " + str(site_id) + ", Meter: " + str(meter) + ", Fold: " + str(k+1))
        plt.ylabel("rmse")
        plt.xlabel("Epoch")
        plt.legend(["train", "valid"], loc="upper right")
        plt.show()
        
        pred_val[valid_idx] = model.predict(X_valid).ravel()
        pred_test += model.predict(X_test).ravel() / cv
        
        gc.collect()
        
    df_valid = pd.DataFrame({"site_id": site_id, "meter": meter, "meter_reading": np.expm1(y_train_site_meter), "pred_ffnn": np.clip(np.expm1(pred_val), 0, a_max=None)})
    df_pred = pd.DataFrame({"row_id": row_ids_test, "meter_reading": np.clip(np.expm1(pred_test), 0, a_max=None)})
    
    df_cv.append(df_valid)
    df_preds.append(df_pred)
    
    gc.collect()
    
    print("\nCV RMSE for Site:", site_id, "and Meter:", meter, "is", np.sqrt(mean_squared_error(np.log1p(df_valid.meter_reading), np.log1p(df_valid.pred_ffnn))))

df_cv = pd.concat(df_cv)
print("\nCV RMSE for Site:", site_id, "is", np.sqrt(mean_squared_error(np.log1p(df_cv.meter_reading), np.log1p(df_cv.pred_ffnn))))
# Out:
# Building Model for site_id 8 and meter 0
# Preparing Site: 8 , meter: 0 , Fold: 1
# WARNING:tensorflow:From C:\Users\sbbpan\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\sbbpan\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\sbbpan\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\sbbpan\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\Users\sbbpan\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\Users\sbbpan\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 449609 samples, validate on 112403 samples
# Epoch 1/41
#  - 8s - loss: 2.3021 - val_loss: 1.2870
# Epoch 2/41
#  - 6s - loss: 1.5582 - val_loss: 1.6064
# Epoch 3/41
#  - 6s - loss: 1.4765 - val_loss: 1.5692
# Epoch 4/41
#  - 6s - loss: 1.4314 - val_loss: 1.4921
# Epoch 5/41
#  - 6s - loss: 1.4086 - val_loss: 1.5769
# Epoch 6/41
#  - 6s - loss: 1.3970 - val_loss: 1.5369
# Epoch 7/41
#  - 6s - loss: 1.3918 - val_loss: 1.4346
# Epoch 8/41
#  - 6s - loss: 1.3861 - val_loss: 1.4675
# Epoch 9/41
#  - 6s - loss: 1.3827 - val_loss: 1.4134
# Epoch 10/41
#  - 6s - loss: 1.3782 - val_loss: 1.3844
# Epoch 11/41
#  - 6s - loss: 1.3753 - val_loss: 1.4109
# Epoch 12/41
#  - 6s - loss: 1.3738 - val_loss: 1.3951
# Epoch 13/41
#  - 6s - loss: 1.3713 - val_loss: 1.3743
# Epoch 14/41
#  - 6s - loss: 1.3681 - val_loss: 1.3445
# Epoch 15/41
#  - 6s - loss: 1.3664 - val_loss: 1.3613
# Epoch 16/41
#  - 6s - loss: 1.3636 - val_loss: 1.3290
# Epoch 17/41
#  - 6s - loss: 1.3610 - val_loss: 1.3149
# Epoch 18/41
#  - 6s - loss: 1.3598 - val_loss: 1.3417
# Epoch 19/41
#  - 6s - loss: 1.3574 - val_loss: 1.3160
# Epoch 20/41
#  - 6s - loss: 1.3560 - val_loss: 1.3286
# Epoch 21/41
#  - 6s - loss: 1.3533 - val_loss: 1.3049
# Epoch 22/41
#  - 6s - loss: 1.3519 - val_loss: 1.3105
# Epoch 23/41
#  - 6s - loss: 1.3504 - val_loss: 1.3005
# Epoch 24/41
#  - 6s - loss: 1.3491 - val_loss: 1.3174
# Epoch 25/41
#  - 6s - loss: 1.3475 - val_loss: 1.2887
# Epoch 26/41
#  - 6s - loss: 1.3460 - val_loss: 1.2572
# Epoch 27/41
#  - 6s - loss: 1.3447 - val_loss: 1.3119
# Epoch 28/41
#  - 6s - loss: 1.3423 - val_loss: 1.3041
# Epoch 29/41
#  - 6s - loss: 1.3418 - val_loss: 1.2866
# Epoch 30/41
#  - 6s - loss: 1.3393 - val_loss: 1.2848
# Epoch 31/41
#  - 6s - loss: 1.3384 - val_loss: 1.2699
# Epoch 32/41
#  - 6s - loss: 1.3372 - val_loss: 1.3004
# Epoch 33/41
#  - 6s - loss: 1.3367 - val_loss: 1.2537
# Epoch 34/41
#  - 6s - loss: 1.3352 - val_loss: 1.2980
# Epoch 35/41
#  - 6s - loss: 1.3335 - val_loss: 1.2693
# Epoch 36/41
#  - 6s - loss: 1.3330 - val_loss: 1.2838
# Epoch 37/41
#  - 6s - loss: 1.3317 - val_loss: 1.2566
# Epoch 38/41
#  - 6s - loss: 1.3303 - val_loss: 1.2547
# Epoch 39/41
#  - 6s - loss: 1.3300 - val_loss: 1.2604
# Epoch 40/41
#  - 6s - loss: 1.3278 - val_loss: 1.2638
# Epoch 41/41
#  - 6s - loss: 1.3283 - val_loss: 1.2494
# Preparing Site: 8 , meter: 0 , Fold: 2
# Train on 449609 samples, validate on 112403 samples
# Epoch 1/41
#  - 7s - loss: 2.2105 - val_loss: 1.1929
# Epoch 2/41
#  - 6s - loss: 1.6435 - val_loss: 1.1054
# Epoch 3/41
#  - 6s - loss: 1.5731 - val_loss: 1.1213
# Epoch 4/41
#  - 6s - loss: 1.5330 - val_loss: 1.1471
# Epoch 5/41
#  - 6s - loss: 1.5131 - val_loss: 1.0870
# Epoch 6/41
#  - 6s - loss: 1.5039 - val_loss: 1.0996
# Epoch 7/41
#  - 6s - loss: 1.4971 - val_loss: 1.0713
# Epoch 8/41
#  - 6s - loss: 1.4932 - val_loss: 1.0793
# Epoch 9/41
#  - 6s - loss: 1.4894 - val_loss: 1.0892
# Epoch 10/41
#  - 6s - loss: 1.4866 - val_loss: 1.0702
# Epoch 11/41
#  - 6s - loss: 1.4842 - val_loss: 1.0818
# Epoch 12/41
#  - 6s - loss: 1.4814 - val_loss: 1.0366
# Epoch 13/41
#  - 6s - loss: 1.4788 - val_loss: 1.0652
# Epoch 14/41
#  - 6s - loss: 1.4761 - val_loss: 1.0561
# Epoch 15/41
#  - 6s - loss: 1.4745 - val_loss: 1.0619
# Epoch 16/41
#  - 6s - loss: 1.4728 - val_loss: 1.0489
# Epoch 17/41
#  - 5s - loss: 1.4705 - val_loss: 1.0801
# Epoch 18/41
#  - 6s - loss: 1.4691 - val_loss: 1.0458
# Epoch 19/41
#  - 5s - loss: 1.4666 - val_loss: 1.0411
# Epoch 20/41
#  - 6s - loss: 1.4677 - val_loss: 1.0485
# Epoch 21/41
#  - 5s - loss: 1.4636 - val_loss: 1.0412
# Epoch 22/41
#  - 6s - loss: 1.4642 - val_loss: 1.0337
# Epoch 23/41
#  - 5s - loss: 1.4617 - val_loss: 1.0597
# Epoch 24/41
#  - 6s - loss: 1.4609 - val_loss: 1.0176
# Epoch 25/41
#  - 5s - loss: 1.4589 - val_loss: 1.0757
# Epoch 26/41
#  - 6s - loss: 1.4583 - val_loss: 1.0265
# Epoch 27/41
#  - 6s - loss: 1.4573 - val_loss: 1.0494
# Epoch 28/41
#  - 6s - loss: 1.4567 - val_loss: 1.0509
# Epoch 29/41
#  - 6s - loss: 1.4547 - val_loss: 1.0319
# Epoch 30/41
#  - 6s - loss: 1.4533 - val_loss: 1.0516
# Epoch 31/41
#  - 6s - loss: 1.4533 - val_loss: 1.0422
# Epoch 32/41
#  - 6s - loss: 1.4522 - val_loss: 1.0464
# Epoch 33/41
#  - 6s - loss: 1.4503 - val_loss: 1.0556
# Epoch 34/41
#  - 6s - loss: 1.4496 - val_loss: 1.0527
# Epoch 35/41
#  - 6s - loss: 1.4490 - val_loss: 1.0540
# Epoch 36/41
#  - 6s - loss: 1.4476 - val_loss: 1.0695
# Epoch 37/41
#  - 6s - loss: 1.4466 - val_loss: 1.0595
# Epoch 38/41
#  - 6s - loss: 1.4464 - val_loss: 1.0617
# Epoch 39/41
#  - 6s - loss: 1.4456 - val_loss: 1.0618
# Epoch 40/41
#  - 6s - loss: 1.4443 - val_loss: 1.0754
# Epoch 41/41
#  - 6s - loss: 1.4434 - val_loss: 1.0650
# Preparing Site: 8 , meter: 0 , Fold: 3
# Train on 449610 samples, validate on 112402 samples
# Epoch 1/41
#  - 8s - loss: 2.1562 - val_loss: 1.2135
# Epoch 2/41
#  - 6s - loss: 1.6308 - val_loss: 1.0085
# Epoch 3/41
#  - 6s - loss: 1.5800 - val_loss: 0.9933
# Epoch 4/41
#  - 6s - loss: 1.5447 - val_loss: 1.0798
# Epoch 5/41
#  - 6s - loss: 1.5260 - val_loss: 0.9764
# Epoch 6/41
#  - 6s - loss: 1.5134 - val_loss: 1.0738
# Epoch 7/41
#  - 6s - loss: 1.5053 - val_loss: 0.9958
# Epoch 8/41
#  - 6s - loss: 1.5014 - val_loss: 1.0103
# Epoch 9/41
#  - 6s - loss: 1.4967 - val_loss: 1.0005
# Epoch 10/41
#  - 7s - loss: 1.4939 - val_loss: 1.0279
# Epoch 11/41
#  - 6s - loss: 1.4908 - val_loss: 1.0353
# Epoch 12/41
#  - 6s - loss: 1.4891 - val_loss: 1.0550
# Epoch 13/41
#  - 6s - loss: 1.4865 - val_loss: 1.0056
# Epoch 14/41
#  - 6s - loss: 1.4849 - val_loss: 1.0396
# Epoch 15/41
#  - 6s - loss: 1.4812 - val_loss: 1.0219
# Epoch 16/41
#  - 6s - loss: 1.4795 - val_loss: 1.0324
# Epoch 17/41
#  - 6s - loss: 1.4782 - val_loss: 1.0102
# Epoch 18/41
#  - 6s - loss: 1.4767 - val_loss: 1.0190
# Epoch 19/41
#  - 6s - loss: 1.4765 - val_loss: 1.0128
# Epoch 20/41
#  - 6s - loss: 1.4736 - val_loss: 1.0354
# Epoch 21/41
#  - 6s - loss: 1.4721 - val_loss: 1.0105
# Epoch 22/41
#  - 6s - loss: 1.4714 - val_loss: 1.0313
# Epoch 23/41
#  - 6s - loss: 1.4689 - val_loss: 1.0116
# Epoch 24/41
#  - 6s - loss: 1.4685 - val_loss: 1.0250
# Epoch 25/41
#  - 6s - loss: 1.4670 - val_loss: 1.0133
# Epoch 26/41
#  - 6s - loss: 1.4655 - val_loss: 1.0179
# Epoch 27/41
#  - 6s - loss: 1.4651 - val_loss: 1.0282
# Epoch 28/41
#  - 6s - loss: 1.4635 - val_loss: 1.0173
# Epoch 29/41
#  - 6s - loss: 1.4628 - val_loss: 1.0257
# Epoch 30/41
#  - 6s - loss: 1.4603 - val_loss: 1.0291
# Epoch 31/41
#  - 6s - loss: 1.4603 - val_loss: 1.0360
# Epoch 32/41
#  - 6s - loss: 1.4583 - val_loss: 1.0275
# Epoch 33/41
#  - 6s - loss: 1.4583 - val_loss: 1.0298
# Epoch 34/41
#  - 6s - loss: 1.4568 - val_loss: 1.0399
# Epoch 35/41
#  - 6s - loss: 1.4556 - val_loss: 1.0339
# Epoch 36/41
#  - 6s - loss: 1.4543 - val_loss: 1.0494
# Epoch 37/41
#  - 6s - loss: 1.4544 - val_loss: 1.0413
# Epoch 38/41
#  - 6s - loss: 1.4531 - val_loss: 1.0533
# Epoch 39/41
#  - 6s - loss: 1.4526 - val_loss: 1.0389
# Epoch 40/41
#  - 6s - loss: 1.4515 - val_loss: 1.0434
# Epoch 41/41
#  - 6s - loss: 1.4508 - val_loss: 1.0410
# Preparing Site: 8 , meter: 0 , Fold: 4
# Train on 449610 samples, validate on 112402 samples
# Epoch 1/41
#  - 8s - loss: 2.0800 - val_loss: 1.6563
# Epoch 2/41
#  - 6s - loss: 1.4757 - val_loss: 1.7460
# Epoch 3/41
#  - 6s - loss: 1.4239 - val_loss: 1.7341
# Epoch 4/41
#  - 8s - loss: 1.3877 - val_loss: 1.7109
# Epoch 5/41
#  - 7s - loss: 1.3688 - val_loss: 1.6736
# Epoch 6/41
#  - 7s - loss: 1.3591 - val_loss: 1.6772
# Epoch 7/41
#  - 7s - loss: 1.3527 - val_loss: 1.6266
# Epoch 8/41
#  - 6s - loss: 1.3477 - val_loss: 1.6173
# Epoch 9/41
#  - 6s - loss: 1.3438 - val_loss: 1.6296
# Epoch 10/41
#  - 7s - loss: 1.3407 - val_loss: 1.5901
# Epoch 11/41
#  - 7s - loss: 1.3379 - val_loss: 1.6202
# Epoch 12/41
#  - 6s - loss: 1.3355 - val_loss: 1.5909
# Epoch 13/41
#  - 7s - loss: 1.3337 - val_loss: 1.6078
# Epoch 14/41
#  - 6s - loss: 1.3303 - val_loss: 1.5967
# Epoch 15/41
#  - 6s - loss: 1.3285 - val_loss: 1.6110
# Epoch 16/41
#  - 7s - loss: 1.3259 - val_loss: 1.6141
# Epoch 17/41
#  - 6s - loss: 1.3246 - val_loss: 1.6211
# Epoch 18/41
#  - 6s - loss: 1.3226 - val_loss: 1.5705
# Epoch 19/41
#  - 6s - loss: 1.3197 - val_loss: 1.5767
# Epoch 20/41
#  - 7s - loss: 1.3184 - val_loss: 1.6009
# Epoch 21/41
#  - 6s - loss: 1.3175 - val_loss: 1.5802
# Epoch 22/41
#  - 7s - loss: 1.3165 - val_loss: 1.5537
# Epoch 23/41
#  - 6s - loss: 1.3150 - val_loss: 1.5617
# Epoch 24/41
#  - 7s - loss: 1.3129 - val_loss: 1.5712
# Epoch 25/41
#  - 7s - loss: 1.3124 - val_loss: 1.5579
# Epoch 26/41
#  - 7s - loss: 1.3105 - val_loss: 1.5768
# Epoch 27/41
#  - 7s - loss: 1.3097 - val_loss: 1.5469
# Epoch 28/41
#  - 6s - loss: 1.3078 - val_loss: 1.5624
# Epoch 29/41
#  - 6s - loss: 1.3065 - val_loss: 1.5339
# Epoch 30/41
#  - 6s - loss: 1.3044 - val_loss: 1.5636
# Epoch 31/41
#  - 6s - loss: 1.3040 - val_loss: 1.5356
# Epoch 32/41
#  - 6s - loss: 1.3032 - val_loss: 1.5513
# Epoch 33/41
#  - 6s - loss: 1.3014 - val_loss: 1.5367
# Epoch 34/41
#  - 6s - loss: 1.3005 - val_loss: 1.5505
# Epoch 35/41
#  - 6s - loss: 1.2987 - val_loss: 1.5403
# Epoch 36/41
#  - 7s - loss: 1.2971 - val_loss: 1.5451
# Epoch 37/41
#  - 6s - loss: 1.2965 - val_loss: 1.5387
# Epoch 38/41
#  - 6s - loss: 1.2962 - val_loss: 1.5368
# Epoch 39/41
#  - 7s - loss: 1.2947 - val_loss: 1.5290
# Epoch 40/41
#  - 6s - loss: 1.2929 - val_loss: 1.5435
# Epoch 41/41
#  - 6s - loss: 1.2919 - val_loss: 1.5397
# Preparing Site: 8 , meter: 0 , Fold: 5
# Train on 449610 samples, validate on 112402 samples
# Epoch 1/41
#  - 10s - loss: 2.0100 - val_loss: 2.1064
# Epoch 2/41
#  - 7s - loss: 1.4964 - val_loss: 1.6707
# Epoch 3/41
#  - 7s - loss: 1.4172 - val_loss: 1.7341
# Epoch 4/41
#  - 8s - loss: 1.3807 - val_loss: 1.5291
# Epoch 5/41
#  - 7s - loss: 1.3596 - val_loss: 1.5398
# Epoch 6/41
#  - 7s - loss: 1.3498 - val_loss: 1.5187
# Epoch 7/41
#  - 7s - loss: 1.3435 - val_loss: 1.5201
# Epoch 8/41
#  - 7s - loss: 1.3384 - val_loss: 1.4770
# Epoch 9/41
#  - 7s - loss: 1.3352 - val_loss: 1.4786
# Epoch 10/41
#  - 7s - loss: 1.3324 - val_loss: 1.5169
# Epoch 11/41
#  - 7s - loss: 1.3309 - val_loss: 1.4977
# Epoch 12/41
#  - 7s - loss: 1.3282 - val_loss: 1.5567
# Epoch 13/41
#  - 6s - loss: 1.3256 - val_loss: 1.4732
# Epoch 14/41
#  - 7s - loss: 1.3240 - val_loss: 1.5317
# Epoch 15/41
#  - 7s - loss: 1.3221 - val_loss: 1.5326
# Epoch 16/41
#  - 7s - loss: 1.3193 - val_loss: 1.4970
# Epoch 17/41
#  - 7s - loss: 1.3191 - val_loss: 1.5151
# Epoch 18/41
#  - 7s - loss: 1.3172 - val_loss: 1.5207
# Epoch 19/41
#  - 7s - loss: 1.3158 - val_loss: 1.5002
# Epoch 20/41
#  - 8s - loss: 1.3139 - val_loss: 1.5234
# Epoch 21/41
#  - 8s - loss: 1.3133 - val_loss: 1.5024
# Epoch 22/41
#  - 8s - loss: 1.3103 - val_loss: 1.5134
# Epoch 23/41
#  - 8s - loss: 1.3095 - val_loss: 1.5025
# Epoch 24/41
#  - 9s - loss: 1.3087 - val_loss: 1.5107
# Epoch 25/41
#  - 8s - loss: 1.3076 - val_loss: 1.5068
# Epoch 26/41
#  - 7s - loss: 1.3077 - val_loss: 1.5368
# Epoch 27/41
#  - 8s - loss: 1.3056 - val_loss: 1.4950
# Epoch 28/41
#  - 8s - loss: 1.3047 - val_loss: 1.5662
# Epoch 29/41
#  - 8s - loss: 1.3031 - val_loss: 1.5128
# Epoch 30/41
#  - 7s - loss: 1.3026 - val_loss: 1.5325
# Epoch 31/41
#  - 7s - loss: 1.3019 - val_loss: 1.5014
# Epoch 32/41
#  - 8s - loss: 1.3006 - val_loss: 1.5238
# Epoch 33/41
#  - 7s - loss: 1.2992 - val_loss: 1.5147
# Epoch 34/41
#  - 8s - loss: 1.2992 - val_loss: 1.5045
# Epoch 35/41
#  - 9s - loss: 1.2986 - val_loss: 1.5265
# Epoch 36/41
#  - 8s - loss: 1.2972 - val_loss: 1.5198
# Epoch 37/41
#  - 9s - loss: 1.2962 - val_loss: 1.5112
# Epoch 38/41
#  - 10s - loss: 1.2947 - val_loss: 1.4961
# Epoch 39/41
#  - 8s - loss: 1.2945 - val_loss: 1.5251
# Epoch 40/41
#  - 8s - loss: 1.2948 - val_loss: 1.5002
# Epoch 41/41
#  - 8s - loss: 1.2927 - val_loss: 1.5005
# CV RMSE for Site: 8 and Meter: 0 is 1.5073399806455692
#
# CV RMSE for Site: 8 is 1.5073399806455692

# %%
df_preds = pd.concat(df_preds)
df_preds.to_csv("../sub/ffnn_pred_site_" + str(site_id) + ".csv", index=False)
